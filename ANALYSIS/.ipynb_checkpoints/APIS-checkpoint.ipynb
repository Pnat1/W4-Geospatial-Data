# %% [markdown]
# ### Geocoding API

# %%
import requests
from urllib.parse import urlencode
from dotenv import load_dotenv
import os
from urllib.parse import urlparse, parse_qsl
from pymongo import MongoClient
import json

# %%
load_dotenv()
# Out:
# True

# %%
api_google_maps = os.getenv("api_google_maps")

# %% [markdown]
# ##### Geocode Api de Compañía de Madrid

# %%
data_type = "json"
enpoint = f"https://maps.googleapis.com/maps/api/geocode/{data_type}"
params = {"address": "Calle Quintanavides 15, Madrid, Comunidad de Madrid", "key": api_google_maps}
url_params = urlencode(params)

new_url = f"{enpoint}?{url_params}"

print(new_url)
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?address=Calle+Quintanavides+15%2C+Madrid%2C+Comunidad+de+Madrid&key=AIzaSyCxqMwAc8B_fQz9nWEqnnPh64v7SBZ5IEM

# %%
def extract_lat_lng(address_or_postalcode, data_type = "json"):
    enpoint = f"https://maps.googleapis.com/maps/api/geocode/{data_type}"
    params = {"address": address_or_postalcode, "key": api_google_maps}
    url_params = urlencode(params)              
    new_url = f"{enpoint}?{url_params}"
    r = requests.get(new_url)
    if r.status_code not in range(200, 299):
        return {}
    latlng = {}
    try:
        latlng = r.json()["results"][0]["geometry"]["location"]
    except:
        pass
    return latlng.get("lat"), latlng.get("lng")

# %%
extract_lat_lng("Calle Quintanavides 15, Madrid, Comunidad de Madrid")
# Out:
# (40.4977863, -3.6697489)

# %%
to_parse = "https://maps.googleapis.com/maps/api/geocode/json?address=Calle+Quintanavides+15%2C+Madrid%2C+Comunidad+de+Madrid&key=AIzaSyCxqMwAc8B_fQz9nWEqnnPh64v7SBZ5IEM"

# %%
urlparse(to_parse)
# Out:
# ParseResult(scheme='https', netloc='maps.googleapis.com', path='/maps/api/geocode/json', params='', query='address=Calle+Quintanavides+15%2C+Madrid%2C+Comunidad+de+Madrid&key=AIzaSyCxqMwAc8B_fQz9nWEqnnPh64v7SBZ5IEM', fragment='')

# %%
parsed_url = urlparse(to_parse)
query_string = parsed_url.query
query_string
# Out:
# 'address=Calle+Quintanavides+15%2C+Madrid%2C+Comunidad+de+Madrid&key=AIzaSyCxqMwAc8B_fQz9nWEqnnPh64v7SBZ5IEM'

# %%
query_tuple = parse_qsl(query_string)
print(query_tuple)
# Out:
# [('address', 'Calle Quintanavides 15, Madrid, Comunidad de Madrid'), ('key', 'AIzaSyCxqMwAc8B_fQz9nWEqnnPh64v7SBZ5IEM')]

# %%
query_dict = dict(query_tuple)
query_dict
# Out:
# {'address': 'Calle Quintanavides 15, Madrid, Comunidad de Madrid',
#  'key': 'AIzaSyCxqMwAc8B_fQz9nWEqnnPh64v7SBZ5IEM'}

# %%
endpoint = f"{parsed_url.scheme}://{parsed_url.netloc}{parsed_url.path}"
print(endpoint)
# Out:
# https://maps.googleapis.com/maps/api/geocode/json

# %% [markdown]
# ###  Places API

# %%
# Vamos a hacer places solo 
# Con el lat y lng de las empresas que hemos escogido que nos dan las coordenadas de las ciudades que queremos
# la respuesta de data la convertiremos en json como hace el americano
# luego de vul

# %% [markdown]
# ##### Geocode Api de Compañía de Madrid la más cerca

# %%
lat, lng = (40.4977863, -3.6697489)
base_enpoint_places = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
params = {
    "key": api_google_maps,
    "input": "Tech Companies",
    "inputtype": "textquery",
    "fields": "formatted_address,name,geometry,permanently_closed,business_status"
}
locationbias = f"circle:{lat},{lng}"
use_circular = True
if use_circular:
    radius = 400
    locationbias = f"circle:{radius}@{lat},{lng}"

params["locationbias"] = locationbias
    
params_encoded = urlencode(params)
places_endpoint = f"{base_enpoint_places}?{params_encoded}"
print(places_endpoint)
# Out:
# https://maps.googleapis.com/maps/api/place/findplacefromtext/json?key=AIzaSyCxqMwAc8B_fQz9nWEqnnPh64v7SBZ5IEM&input=Tech+Companies&inputtype=textquery&fields=formatted_address%2Cname%2Cgeometry%2Cpermanently_closed%2Cbusiness_status&locationbias=circle%3A400%4040.4977863%2C-3.6697489

# %%
r = requests.get(places_endpoint)
print(r.status_code)
# Out:
# 200

# %%
r.json()
# Out:
# {'candidates': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'Av. de Manoteras, 44, 28050 Madrid, España',
#    'geometry': {'location': {'lat': 40.48714409999999, 'lng': -3.6645864},
#     'viewport': {'northeast': {'lat': 40.48857142989272,
#       'lng': -3.663428670107278},
#      'southwest': {'lat': 40.48587177010727, 'lng': -3.666128329892722}}},
#    'name': 'BBVA Next Technologies'}],
#  'status': 'OK'}

# %% [markdown]
# ### Nearby Places API Radius

# %% [markdown]
# ###### Madrid Company

# %% [markdown]
# Tech Companies near Madrid's company found through coordinates from "companies" dataframe in Mongo.

# %%
techs_endpoint = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params_2 = {
    "key": api_google_maps,
    "location": f"{lat},{lng}",
    "radius": 500,
    "keyword": "Tech Companies"
}
params_2_encoded = urlencode(params_2)
techs_url = f"{techs_endpoint}?{params_2_encoded}"

r2 = requests.get(techs_url)

# %%
r2.json()
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.5027322, 'lng': -3.6718831},
#     'viewport': {'northeast': {'lat': 40.50414192989273,
#       'lng': -3.670619770107277},
#      'southwest': {'lat': 40.50144227010728, 'lng': -3.673319429892721}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Verbio Technologies- Madrid Office',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 512,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107204109335243508929">A Google User</a>'],
#      'photo_reference': 'Aap_uEBZ_sR3pTsPh5FvZ2qI-g7A_QybeIcwggI8P8onN8ay7RJzupmKleNgQTJqwA4qwj6JwQCaerpZCamwFILRZpksPpiHI5qdji2Ls1wZPcddNrX0ydgRHZVpdQy-XqLf_uGdVOq59YPHgxi4-uAzuW2HFzkp7UCFDlg1GvgqnNqnkSHh',
#      'width': 1024}],
#    'place_id': 'ChIJs42vLPsrQg0RYGQRc4BCbRQ',
#    'plus_code': {'compound_code': 'G83H+36 Madrid',
#     'global_code': '8CGRG83H+36'},
#    'rating': 5,
#    'reference': 'ChIJs42vLPsrQg0RYGQRc4BCbRQ',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Calle de Anabel Segura, 10, Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.5007364, 'lng': -3.6678272},
#     'viewport': {'northeast': {'lat': 40.50204857989272,
#       'lng': -3.666576870107278},
#      'southwest': {'lat': 40.49934892010728, 'lng': -3.669276529892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'AS Software',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1125,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116224506220888050362">AS Software</a>'],
#      'photo_reference': 'Aap_uEB4_Wsa4RcNvq2wMLvRYaviddWoHmAnKzP3sX9qozShS2kRnYXWpUBu0fIr38Q-uY_bdAJQg9UzLLxNr1xce_OaL2RgmQ8benw51G0jmBkdmFDGdEXgYMB2cNcq2UwQwJ2nWwTmIGzeKIaa5Z2nykao8EpuSXlwk77wV1ELeiwVElW7',
#      'width': 1500}],
#    'place_id': 'ChIJSfbT8PsrQg0R-sM68PFI5p8',
#    'plus_code': {'compound_code': 'G82J+7V Madrid',
#     'global_code': '8CGRG82J+7V'},
#    'rating': 4.6,
#    'reference': 'ChIJSfbT8PsrQg0R-sM68PFI5p8',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': 'C. Sauceda, 10, Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.4937654, 'lng': -3.6710505},
#     'viewport': {'northeast': {'lat': 40.49511522989273,
#       'lng': -3.669700670107278},
#      'southwest': {'lat': 40.49241557010728, 'lng': -3.672400329892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Abbott Informatics Spain',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101787199739254083210">A Google User</a>'],
#      'photo_reference': 'Aap_uECTDecBff9S-z1ChRyVMzHMabD-HgoQcBFP7BaidhAJvpI5o874EpsV7aqj01JZs9u0EFIGPJRGA58W4I98QaDhLgmjSNiqSXVGIjDwyEs6fyB_HpVaKJ3dOrQVGdqKQw8N6bENMooNQPSiRM5MWAEdW25msIrLdDgrACuiVm0IE49x',
#      'width': 4032}],
#    'place_id': 'ChIJ_flKjoQpQg0RjqWLdzxrN90',
#    'plus_code': {'compound_code': 'F8VH+GH Madrid',
#     'global_code': '8CGRF8VH+GH'},
#    'rating': 4.3,
#    'reference': 'ChIJ_flKjoQpQg0RjqWLdzxrN90',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'A-1 Vía de Servicio, 91, edificio 4, Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.495166, 'lng': -3.6651568},
#     'viewport': {'northeast': {'lat': 40.49673832989272,
#       'lng': -3.663505920107278},
#      'southwest': {'lat': 40.49403867010728, 'lng': -3.666205579892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Teradata Iberia SLU',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109122732180137447324">Fernando Sánchez</a>'],
#      'photo_reference': 'Aap_uEAkiVACOa1pCjP380v3OMSs4zEcqzLahXR_dln5KgYTE8x8OSLB4ck7P780qsnuhnABWVO6nhqyvcTMGhFFP39sDgNt37Jy4rVkWw1lZ8ASzfkpdCuc4xbBnBINXElchxD5_8DEBB9iXcZ7ztKdq-awAN5ucEhUFl7JlArV8I6rn74Z',
#      'width': 4032}],
#    'place_id': 'ChIJH5Lhh1UpQg0R7LoOYDn1HfY',
#    'plus_code': {'compound_code': 'F8WM+3W Madrid',
#     'global_code': '8CGRF8WM+3W'},
#    'rating': 5,
#    'reference': 'ChIJH5Lhh1UpQg0R7LoOYDn1HfY',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 10,
#    'vicinity': 'Iberia, C. de María de Portugal, 1, 3-5 Edificio 2, Planta 1, Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.4981698, 'lng': -3.6705217},
#     'viewport': {'northeast': {'lat': 40.49951962989272,
#       'lng': -3.669171870107278},
#      'southwest': {'lat': 40.49681997010728, 'lng': -3.671871529892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Tecsisa',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116127234361819062877">Renato P.</a>'],
#      'photo_reference': 'Aap_uEDxDv98kJLdevC_kyNWA3QwVMbu3Yx-hOecV4Lyb38em2mOlLgImdOw484V6Fd42ZvBp5rrEzc1EF6YQTI8V2-chiHqUjaWZRQDDVmqHLs0zEPil8GuEi4WasYcqWqUrGFOBZfXlYtleLlP2887nfiaytXQX5DdLngt9PqaIfC3IPuT',
#      'width': 4608}],
#    'place_id': 'ChIJrTFDm08pQg0RhHRy6ASWedo',
#    'plus_code': {'compound_code': 'F8XH+7Q Madrid',
#     'global_code': '8CGRF8XH+7Q'},
#    'rating': 5,
#    'reference': 'ChIJrTFDm08pQg0RhHRy6ASWedo',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': 'Planta 3, C. Quintanavides, 19, Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.4962682, 'lng': -3.6722272},
#     'viewport': {'northeast': {'lat': 40.49741087989273,
#       'lng': -3.670882320107277},
#      'southwest': {'lat': 40.49471122010728, 'lng': -3.673581979892721}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Waavi',
#    'place_id': 'ChIJ39hQPmwrQg0RBk6WU5VCZj4',
#    'plus_code': {'compound_code': 'F8WH+G4 Madrid',
#     'global_code': '8CGRF8WH+G4'},
#    'rating': 0,
#    'reference': 'ChIJ39hQPmwrQg0RBk6WU5VCZj4',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Edificio Oxxeo, C. Puerto de Somport, 9, Planta Baja, Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.49941829999999, 'lng': -3.6669517},
#     'viewport': {'northeast': {'lat': 40.50072607989272,
#       'lng': -3.665711320107279},
#      'southwest': {'lat': 40.49802642010728, 'lng': -3.668410979892723}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Tahbit Software',
#    'place_id': 'ChIJNR-fX_4rQg0Rw2IgHfRByf0',
#    'plus_code': {'compound_code': 'F8XM+Q6 Madrid',
#     'global_code': '8CGRF8XM+Q6'},
#    'rating': 4,
#    'reference': 'ChIJNR-fX_4rQg0Rw2IgHfRByf0',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'C. Quintanapalla, 8, Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.5026051, 'lng': -3.6710736},
#     'viewport': {'northeast': {'lat': 40.50388827989272,
#       'lng': -3.669625270107278},
#      'southwest': {'lat': 40.50118862010728, 'lng': -3.672324929892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Algoritia',
#    'place_id': 'ChIJVVUlH_srQg0RhIlg0f2J4L0',
#    'plus_code': {'compound_code': 'G83H+2H Madrid',
#     'global_code': '8CGRG83H+2H'},
#    'rating': 0,
#    'reference': 'ChIJVVUlH_srQg0RhIlg0f2J4L0',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'C. de la Sierra de Atapuerca, 13, Madrid'}],
#  'status': 'OK'}

# %% [markdown]
# Transport information near given company Madrid location

# %%
transport_endpoint = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params_3 = {
    "key": api_google_maps,
    "location": f"{lat},{lng}",
    "radius": 300,
    "keyword": "Public Transport"
}
params_3_encoded = urlencode(params_3)
trans_url = f"{transport_endpoint}?{params_3_encoded}"

r3 = requests.get(trans_url)

# %%
r3.json()
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.4968012, 'lng': -3.667288},
#     'viewport': {'northeast': {'lat': 40.49812832989272,
#       'lng': -3.665973570107278},
#      'southwest': {'lat': 40.49542867010727, 'lng': -3.668673229892721}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Quintanavides - Av. de Burgos',
#    'place_id': 'ChIJdc0Odf4rQg0RYv2b2VVfmR4',
#    'plus_code': {'compound_code': 'F8WM+P3 Madrid',
#     'global_code': '8CGRF8WM+P3'},
#    'rating': 0,
#    'reference': 'ChIJdc0Odf4rQg0RYv2b2VVfmR4',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.499915, 'lng': -3.67423},
#     'viewport': {'northeast': {'lat': 40.50127907989272,
#       'lng': -3.672965470107277},
#      'southwest': {'lat': 40.49857942010728, 'lng': -3.675665129892721}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Av. Cº Santiago - Sierra Atapuerca',
#    'place_id': 'ChIJCQWEZOMrQg0RYcE7ECICKIY',
#    'plus_code': {'compound_code': 'F8XG+X8 Madrid',
#     'global_code': '8CGRF8XG+X8'},
#    'rating': 0,
#    'reference': 'ChIJCQWEZOMrQg0RYcE7ECICKIY',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.50134, 'lng': -3.666975},
#     'viewport': {'northeast': {'lat': 40.50269437989272,
#       'lng': -3.665628220107279},
#      'southwest': {'lat': 40.49999472010727, 'lng': -3.668327879892723}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Sauceda - Juan Agüi',
#    'place_id': 'ChIJNw68W_krQg0RMGVpNXTPopY',
#    'plus_code': {'compound_code': 'G82M+G6 Madrid',
#     'global_code': '8CGRG82M+G6'},
#    'rating': 0,
#    'reference': 'ChIJNw68W_krQg0RMGVpNXTPopY',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.502215, 'lng': -3.67582},
#     'viewport': {'northeast': {'lat': 40.50356832989272,
#       'lng': -3.674452970107278},
#      'southwest': {'lat': 40.50086867010728, 'lng': -3.677152629892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Castiello de Jaca - Pte. de la Reina',
#    'place_id': 'ChIJ_e0OT-QrQg0RWX3dhmTUbYQ',
#    'plus_code': {'compound_code': 'G82F+VM Madrid',
#     'global_code': '8CGRG82F+VM'},
#    'rating': 0,
#    'reference': 'ChIJ_e0OT-QrQg0RWX3dhmTUbYQ',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.49701, 'lng': -3.66733},
#     'viewport': {'northeast': {'lat': 40.49835737989272,
#       'lng': -3.665984020107278},
#      'southwest': {'lat': 40.49565772010728, 'lng': -3.668683679892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Quintanavides',
#    'place_id': 'ChIJG8oNdv4rQg0Rn3QsXCc-ywY',
#    'plus_code': {'compound_code': 'F8WM+R3 Madrid',
#     'global_code': '8CGRF8WM+R3'},
#    'rating': 0,
#    'reference': 'ChIJG8oNdv4rQg0Rn3QsXCc-ywY',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.49684, 'lng': -3.67353},
#     'viewport': {'northeast': {'lat': 40.49817842989272,
#       'lng': -3.672235470107277},
#      'southwest': {'lat': 40.49547877010728, 'lng': -3.674935129892721}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Camino De Santiago - Valcarlos',
#    'photos': [{'height': 1536,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110177491830391647810">ANGEL ROLAN</a>'],
#      'photo_reference': 'Aap_uEDpkAB5mYOFqExXcU6KV0AlTZLMiGXU_SKkh3Ewk7IEc66yR4tcvWDUtd6LLYdyJBrQKNE2YWfGsD2sSdPuWkHDp_yynsOJlWZNY65iAgl16KwLQ4f5MM5Wm6AkuplxUQCCXBO8XB1GRquLCING5_z9S95ThtkjbfRsfY6EzcWxrqCz',
#      'width': 2560}],
#    'place_id': 'ChIJw-fFw-IrQg0R261BNIXT8_c',
#    'plus_code': {'compound_code': 'F8WG+PH Madrid',
#     'global_code': '8CGRF8WG+PH'},
#    'rating': 0,
#    'reference': 'ChIJw-fFw-IrQg0R261BNIXT8_c',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.49765, 'lng': -3.67357},
#     'viewport': {'northeast': {'lat': 40.49899982989272,
#       'lng': -3.672220170107278},
#      'southwest': {'lat': 40.49630017010728, 'lng': -3.674919829892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Camino De Santiago - Valcarlos',
#    'place_id': 'ChIJe2p13-IrQg0ROKJktRSlojs',
#    'plus_code': {'compound_code': 'F8XG+3H Madrid',
#     'global_code': '8CGRF8XG+3H'},
#    'rating': 0,
#    'reference': 'ChIJe2p13-IrQg0ROKJktRSlojs',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.50013999999999, 'lng': -3.67072},
#     'viewport': {'northeast': {'lat': 40.50143312989272,
#       'lng': -3.669286420107279},
#      'southwest': {'lat': 40.49873347010728, 'lng': -3.671986079892723}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Valcarlos - Puente La Reina',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108322995595957757578">Albert Gallardo</a>'],
#      'photo_reference': 'Aap_uEC2DSpCfW1raBB7Gz-qvmAuMcPthpKe5GS6W3YFB4WUKh91qB3pPoF5cLRQqka_gufkxzQ9i2yuRIqj61iq43M6qbn_Yq9EFrMmdSJhKiO_E5JkvCpsczSpeW3QBBt6Q6vKLwDfik-nA8YXgYTJEDXFxjZwu1xra0z6OD9iH7VkOyR3',
#      'width': 4032}],
#    'place_id': 'ChIJd4_1nPwrQg0RBPdHv31d6bM',
#    'plus_code': {'compound_code': 'G82H+3P Madrid',
#     'global_code': '8CGRG82H+3P'},
#    'rating': 5,
#    'reference': 'ChIJd4_1nPwrQg0RBPdHv31d6bM',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.50145, 'lng': -3.66689},
#     'viewport': {'northeast': {'lat': 40.50275682989272,
#       'lng': -3.665512070107278},
#      'southwest': {'lat': 40.50005717010728, 'lng': -3.668211729892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Sauceda - Azul',
#    'place_id': 'ChIJFauDXPkrQg0RbfBk14F0Rxo',
#    'plus_code': {'compound_code': 'G82M+H6 Madrid',
#     'global_code': '8CGRG82M+H6'},
#    'rating': 3,
#    'reference': 'ChIJFauDXPkrQg0RbfBk14F0Rxo',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.4948387, 'lng': -3.6646633},
#     'viewport': {'northeast': {'lat': 40.49619762989272,
#       'lng': -3.663336970107278},
#      'southwest': {'lat': 40.49349797010727, 'lng': -3.666036629892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Maria De Portugal-Fco. Pi Y Margall',
#    'place_id': 'ChIJq1B9d1UpQg0RCkD37TZaiNw',
#    'plus_code': {'compound_code': 'F8VP+W4 Madrid',
#     'global_code': '8CGRF8VP+W4'},
#    'rating': 0,
#    'reference': 'ChIJq1B9d1UpQg0RCkD37TZaiNw',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Madrid'}],
#  'status': 'OK'}

# %% [markdown]
# Bar/Cafeteria near given location

# %%
bar_endpoint = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params_4 = {
    "key": api_google_maps,
    "location": f"{lat},{lng}",
    "radius": 600,
    "keyword": "bar"
}
params_4_encoded = urlencode(params_4)
bar_url = f"{bar_endpoint}?{params_4_encoded}"

r4 = requests.get(bar_url)

# %%
r4.json()
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.4956666, 'lng': -3.6755234},
#     'viewport': {'northeast': {'lat': 40.49699322989272,
#       'lng': -3.674275820107279},
#      'southwest': {'lat': 40.49429357010728, 'lng': -3.676975479892723}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#    'name': 'Restaurante El Rincón de Las Tablas',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117141449752184430094">Enrique López Callejas</a>'],
#      'photo_reference': 'Aap_uEBqYGoAR9XOKByjMtOeqZlMXHv9BgNMUeyBm0DpIzEuyd5GNrpdkmOONx5fcJpz8fSNSCZqc3ogeWpXSC4MTu9B-hHBHRXdMe7eNSTmb5sIVTGxWOuDuH5D_Jp1cqdNY8dkzn5P6l5mpcozcFBvZ_GJLPY2NaacGP_1KQ3i0_64NfVp',
#      'width': 4032}],
#    'place_id': 'ChIJs3zkceIrQg0R4qkaSAaGPoc',
#    'plus_code': {'compound_code': 'F8WF+7Q Madrid',
#     'global_code': '8CGRF8WF+7Q'},
#    'price_level': 1,
#    'rating': 3.7,
#    'reference': 'ChIJs3zkceIrQg0R4qkaSAaGPoc',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 700,
#    'vicinity': 'C. Castillo Candanchú, 2, Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.500823, 'lng': -3.671538},
#     'viewport': {'northeast': {'lat': 40.50237582989271,
#       'lng': -3.670560770107278},
#      'southwest': {'lat': 40.49967617010727, 'lng': -3.673260429892721}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Tasty Poke Bar',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112953703146667791703">Alfonso Hidalgo</a>'],
#      'photo_reference': 'Aap_uEDfJ8WxIWwu3MYzPTo9MqdNgv5mj73RYCHb6RQTKm8zf0xXB0j4aEqLnNj1ZYUiN_6ox99iKMUlfhBlwzRtkDuzwtQf1kuwb9hoe0idsJ2psMIVFDQMs-32mk5gYhEXeMnSVR6yWuTdO4_Lj05MYG4T3Rc-Il78bFUAnNIfqpaHSm3I',
#      'width': 4032}],
#    'place_id': 'ChIJZYSxukErQg0Rt3kd49c4QlA',
#    'plus_code': {'compound_code': 'G82H+89 Madrid',
#     'global_code': '8CGRG82H+89'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJZYSxukErQg0Rt3kd49c4QlA',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 517,
#    'vicinity': 'Calle de Puente la Reina, C. Azofra, 27, Local 6, Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.5035523, 'lng': -3.678105},
#     'viewport': {'northeast': {'lat': 40.50484362989272,
#       'lng': -3.676983920107277},
#      'southwest': {'lat': 40.50214397010728, 'lng': -3.679683579892721}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#    'name': 'El Castillo de Las Tablas',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114890823094915212339">A Google User</a>'],
#      'photo_reference': 'Aap_uEBuXcAn8W3ojTINT4LpfIpDvBjn1TTCI73-mWXDVGwPahmS0uS_IamZK1j7iq7xtOK4Y1Mt4Ed1pJ7bbUpzRRiON52DrWMfa51yuoTGNrdS2v3yPqlCL0pgKordqRxfRYoPQQ5UdEn-UZKD7sy5fYV8B6FCTAOZkvW1ybM0a96oblcU',
#      'width': 6240}],
#    'place_id': 'ChIJi6iTvQMrQg0RJjc2LtXbwAE',
#    'plus_code': {'compound_code': 'G83C+CQ Madrid',
#     'global_code': '8CGRG83C+CQ'},
#    'rating': 3.7,
#    'reference': 'ChIJi6iTvQMrQg0RJjc2LtXbwAE',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 110,
#    'vicinity': 'C. Burguete, 16, Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.4981195, 'lng': -3.6608377},
#     'viewport': {'northeast': {'lat': 40.49951247989272,
#       'lng': -3.659730620107279},
#      'southwest': {'lat': 40.49681282010727, 'lng': -3.662430279892723}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#    'name': 'Sherry bar Club del Gourmet',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103747928546828598103">francisco nieto gutierrez</a>'],
#      'photo_reference': 'Aap_uECyTzTisaDHnw18xQyPbgJIEn8Q1no_azgrtQ_gnmu03iThdJIO2w6QRJqwJth9Sb0_O78ZBtfujldP1csMKWQHni4uJWX_rcD9SaQhnH3nWfRUteBDM2c7iRtPsXz3ABVhiCQu_EJn_hA-SErzTNkT7J9qEB7jWeH4YoGhvzoLSPnA',
#      'width': 2560}],
#    'place_id': 'ChIJcch_uMktQg0RC9uy7yp7QWc',
#    'plus_code': {'compound_code': 'F8XQ+6M Madrid',
#     'global_code': '8CGRF8XQ+6M'},
#    'rating': 4.8,
#    'reference': 'ChIJcch_uMktQg0RC9uy7yp7QWc',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 11,
#    'vicinity': 'Madrid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.5044919, 'lng': -3.6749051},
#     'viewport': {'northeast': {'lat': 40.50630037989272,
#       'lng': -3.673105670107279},
#      'southwest': {'lat': 40.50360072010728, 'lng': -3.675805329892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Restaurante Oven',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3600,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113895066991832351700">A Google User</a>'],
#      'photo_reference': 'Aap_uEB9YhQftqYB-Y1s7YWD06RO0OdRg_-jM8XulzCT8nfzIP3dSC7Zqigis1-ULrPH_HX6hUIz80TWNYGBG69Y8RugVSG6jKqa_ZM26iADR95Roc7NiuzMAKHDHI6BjeWDbaSE9AKQb5EJ0rUDM9SR0nxiE0uQ7taLSyYBXKQebtU3mp8',
#      'width': 5400}],
#    'place_id': 'ChIJR7x9neUrQg0RfrwC5ixCuzU',
#    'plus_code': {'compound_code': 'G83G+Q2 Madrid',
#     'global_code': '8CGRG83G+Q2'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJR7x9neUrQg0RfrwC5ixCuzU',
#    'scope': 'GOOGLE',
#    'types': ['meal_delivery',
#     'meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1950,
#    'vicinity': 'C. San Juan de Ortega, 36, Madrid'}],
#  'status': 'OK'}

# %% [markdown]
# ###### London Company

# %%
latlnd, lngldn = (51.543337, -0.172364)

# %% [markdown]
# Near tach companies in London 1000m radius

# %%
techs_endpoint_ldn = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params_5 = {
    "key": api_google_maps,
    "location": f"{latlnd},{lngldn}",
    "radius": 1000,
    "keyword": "Tech Companies"
}
params_5_encoded = urlencode(params_5)
techs_url_ldn = f"{techs_endpoint_ldn}?{params_5_encoded}"

r5 = requests.get(techs_url_ldn)

# %%
r5.json()
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5473213, 'lng': -0.1892146},
#     'viewport': {'northeast': {'lat': 51.54862297989272,
#       'lng': -0.1878524701072778},
#      'southwest': {'lat': 51.54592332010727, 'lng': -0.1905521298927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Serac Technologies',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109387118224083587957">A Google User</a>'],
#      'photo_reference': 'Aap_uEC4nNch2DWvruXVPrGPLT-HbmQshemGhvieVajwO1gmmy3-wopmT0n86R0Tv56zSmwhRNZzFi7DtcBRjkFT52W-tXAsoPBpPSQNhIQT08P3Tk7SPjTlvRMBoe31lhbLB86XKZeuIkrNCsUvvGBStRYju-TrGKCLeki7oilidmYnYwRB',
#      'width': 4032}],
#    'place_id': 'ChIJUUWp83ERdkgRikVIaYrAaK0',
#    'plus_code': {'compound_code': 'GRW6+W8 London, United Kingdom',
#     'global_code': '9C3XGRW6+W8'},
#    'rating': 0,
#    'reference': 'ChIJUUWp83ERdkgRikVIaYrAaK0',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Blackburn Rd, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5417198, 'lng': -0.1593324},
#     'viewport': {'northeast': {'lat': 51.54310102989272,
#       'lng': -0.1579785201072778},
#      'southwest': {'lat': 51.54040137010728, 'lng': -0.1606781798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Victor Apps',
#    'place_id': 'ChIJwY6XGDkbdkgRNWplCZPhvYw',
#    'plus_code': {'compound_code': 'GRRR+M7 London, United Kingdom',
#     'global_code': '9C3XGRRR+M7'},
#    'rating': 0,
#    'reference': 'ChIJwY6XGDkbdkgRNWplCZPhvYw',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': '24 Oppidans Rd, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.550523, 'lng': -0.166118},
#     'viewport': {'northeast': {'lat': 51.55183507989273,
#       'lng': -0.1648413201072778},
#      'southwest': {'lat': 51.54913542010728, 'lng': -0.1675409798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Quantum Zero Technologies Ltd',
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105751791229315644216">Quantum Zero Technologies Ltd</a>'],
#      'photo_reference': 'Aap_uECom59b1woeeA7grK9VsgNfSTlupadO8YRhfNAI_1yOpDIRFbx4Nu3WGyA6ro0VAtZQ5-5fxteYUXQTVjPXqD49Hr9EEWloWfSU13yXx4cSXdcAl-R00IVfl-7VW_nfZP5ZTYGODeYfwU_ZyZ7M_Vu3cqAVWW0tYbFjXX5eMgV8QM3w',
#      'width': 1920}],
#    'place_id': 'ChIJY6_Ov4wadkgRDlHDwYFQOn4',
#    'plus_code': {'compound_code': 'HR2M+6H London, United Kingdom',
#     'global_code': '9C3XHR2M+6H'},
#    'rating': 0,
#    'reference': 'ChIJY6_Ov4wadkgRDlHDwYFQOn4',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Tagore House, 2D Glenloch Rd, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.550621, 'lng': -0.1656159},
#     'viewport': {'northeast': {'lat': 51.55203042989272,
#       'lng': -0.1641163201072778},
#      'southwest': {'lat': 51.54933077010728, 'lng': -0.1668159798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'RemiTech',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJlzFZBDYbdkgR6gyFHT3sHV8',
#    'plus_code': {'compound_code': 'HR2M+6Q London, United Kingdom',
#     'global_code': '9C3XHR2M+6Q'},
#    'rating': 5,
#    'reference': 'ChIJlzFZBDYbdkgR6gyFHT3sHV8',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'c/o FKGB, 201 Haverstock Hill, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5474297, 'lng': -0.1796564},
#     'viewport': {'northeast': {'lat': 51.54873857989272,
#       'lng': -0.1784181701072778},
#      'southwest': {'lat': 51.54603892010728, 'lng': -0.1811178298927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Crossing technologies',
#    'place_id': 'ChIJUyHO3oQadkgRMqvrvCrackc',
#    'plus_code': {'compound_code': 'GRWC+X4 London, United Kingdom',
#     'global_code': '9C3XGRWC+X4'},
#    'rating': 0,
#    'reference': 'ChIJUyHO3oQadkgRMqvrvCrackc',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Regina House, 124 Finchley Rd, London'}],
#  'status': 'OK'}

# %% [markdown]
# Near Public Transport Services in a 400m radius

# %%
trans_endpoint_ldn = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params_6 = {
    "key": api_google_maps,
    "location": f"{latlnd},{lngldn}",
    "radius": 400,
    "keyword": "Public Transport"
}
params_6_encoded = urlencode(params_6)
trans_url_ldn = f"{trans_endpoint_ldn}?{params_6_encoded}"

r6 = requests.get(trans_url_ldn)

# %%
r6.json()
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5419139, 'lng': -0.172091},
#     'viewport': {'northeast': {'lat': 51.54330732989273,
#       'lng': -0.1707564201072778},
#      'southwest': {'lat': 51.54060767010728, 'lng': -0.1734560798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bus-71.png',
#    'icon_background_color': '#10BDFF',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bus_share_taxi_pinlet',
#    'name': 'Avenue Road (Stop H)',
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107430128525970978659">Funmi Koya</a>'],
#      'photo_reference': 'Aap_uEBhC0Ywo2yHNTEPFHt_ORsMhIat1Ys69dRu8kGmUMhLt9MDsENPxCGwrNN3c7JelIeI3Y4Yhb6IBY1qSZVU1zOyEAeEGyiOjM7qO1EireJDlOfaThxIdKluR8cKxxInqzH5KZqkY9kyZbWy7m6TUGczDD44JvlsQzpM9tx-9CXKXNM',
#      'width': 5333}],
#    'place_id': 'ChIJ02gzOJEadkgRv2jYEM9eoPI',
#    'plus_code': {'compound_code': 'GRRH+Q5 London, United Kingdom',
#     'global_code': '9C3XGRRH+Q5'},
#    'rating': 5,
#    'reference': 'ChIJ02gzOJEadkgRv2jYEM9eoPI',
#    'scope': 'GOOGLE',
#    'types': ['bus_station',
#     'transit_station',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5429307, 'lng': -0.1740692},
#     'viewport': {'northeast': {'lat': 51.54425302989272,
#       'lng': -0.1727942201072778},
#      'southwest': {'lat': 51.54155337010728, 'lng': -0.1754938798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Swiss Cottage Station (Stop D)',
#    'place_id': 'ChIJixlh5JAadkgR5pVidYSTrU8',
#    'plus_code': {'compound_code': 'GRVG+59 London, United Kingdom',
#     'global_code': '9C3XGRVG+59'},
#    'rating': 4,
#    'reference': 'ChIJixlh5JAadkgR5pVidYSTrU8',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.542713, 'lng': -0.169903},
#     'viewport': {'northeast': {'lat': 51.54404997989271,
#       'lng': -0.1685488201072778},
#      'southwest': {'lat': 51.54135032010727, 'lng': -0.1712484798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Winchester Road South Hampstead (Stop L)',
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105515696111917562141">Yuno Gueto</a>'],
#      'photo_reference': 'Aap_uEAVxGj2Cx01Bo3rH15I2XkdHrIShz2GmwzHyU09QP2QEy-ON9AoyRm-Ytt9S5E7cUQopeVXL5tZEV8yEJyU5iBCs_gK9dWXOkjLImkGwa4h_zy-R_rAq-J2xLkw7vF07v21iP60Oq6gCWKAIABWZzGOAjpy9CO_8uBDC2ntSD-cwGoP',
#      'width': 3024}],
#    'place_id': 'ChIJI83D3JMadkgRLSOlUUNvGUU',
#    'plus_code': {'compound_code': 'GRVJ+32 London, United Kingdom',
#     'global_code': '9C3XGRVJ+32'},
#    'rating': 0,
#    'reference': 'ChIJI83D3JMadkgRLSOlUUNvGUU',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5469174, 'lng': -0.179986},
#     'viewport': {'northeast': {'lat': 51.54822172989273,
#       'lng': -0.1785647701072778},
#      'southwest': {'lat': 51.54552207010728, 'lng': -0.1812644298927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Finchley Road tube station',
#    'photos': [{'height': 2322,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115348551340047492204">Alex Marks</a>'],
#      'photo_reference': 'Aap_uEBAFevfORu4NgSfr7OJmIPIwNQcrWEubwtjhz6BcHxa_MWE_3WtabhddjzvbxEgHhqQdwhSVnkRVCKyqUk0yNE1aoIWYdmuLQKqbxV7YwNoRUHriwgxFAnE7zfA-q31IIZF46gJWl5xtByUViulV3PPAX3JXohs0tANClCBbnVL4ZLF',
#      'width': 4128}],
#    'place_id': 'ChIJE_1U0IQadkgRc9Z_mCfWokc',
#    'plus_code': {'compound_code': 'GRWC+Q2 London, United Kingdom',
#     'global_code': '9C3XGRWC+Q2'},
#    'rating': 4.7,
#    'reference': 'ChIJE_1U0IQadkgRc9Z_mCfWokc',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': 'London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.542511, 'lng': -0.17369},
#     'viewport': {'northeast': {'lat': 51.54383467989273,
#       'lng': -0.1724156701072778},
#      'southwest': {'lat': 51.54113502010728, 'lng': -0.1751153298927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Swiss Cottage Station (Stop E)',
#    'photos': [{'height': 2477,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108681308870781918461">filippo d&#39;ambrosio</a>'],
#      'photo_reference': 'Aap_uEBKrIm5SC0HtqrUTpC8VhyGStnll15svDIFyXOPGFvKBm6_a46wuEvlR0MB4m1mYPY6HYH1KqjKwttXWSF3baDatFXGoF7IANPWef_WGRu5bjHLUFxj6wRD0qs70QYboVmEIVa0EaNVNyda_pNWlHM2OdYkhchOR4prc93pnD1ZoyrP',
#      'width': 1960}],
#    'place_id': 'ChIJzeSF4JAadkgR-nI_9DzVFyQ',
#    'plus_code': {'compound_code': 'GRVG+2G London, United Kingdom',
#     'global_code': '9C3XGRVG+2G'},
#    'rating': 5,
#    'reference': 'ChIJzeSF4JAadkgR-nI_9DzVFyQ',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5474857, 'lng': -0.1802414},
#     'viewport': {'northeast': {'lat': 51.54883277989273,
#       'lng': -0.1788294201072778},
#      'southwest': {'lat': 51.54613312010728, 'lng': -0.1815290798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Finchley Road Station (Stop CL)',
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100590021541450008957">Renjith Mathew</a>'],
#      'photo_reference': 'Aap_uECExkSa2Z2MFvEsnTGX424a9Hpts8afCMvMfwrUzp0UySmjNkpFVOQZswFIVPSbmzE4BRCSUlgWJBuSsWLex46lOgCPZfW8OZVCVj10HewslEhGHUrLys5fjeMjZOIiYx0m8zRuLhxIh_9HP4R90Fm-UlO50OF16qnUZc6LhOsDtmIv',
#      'width': 3000}],
#    'place_id': 'ChIJTyZbw4QadkgRggsDEj6BzhU',
#    'plus_code': {'compound_code': 'GRW9+XW London, United Kingdom',
#     'global_code': '9C3XGRW9+XW'},
#    'rating': 4,
#    'reference': 'ChIJTyZbw4QadkgRggsDEj6BzhU',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 7,
#    'vicinity': 'London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.548195, 'lng': -0.180587},
#     'viewport': {'northeast': {'lat': 51.54953887989272,
#       'lng': -0.1792547701072778},
#      'southwest': {'lat': 51.54683922010727, 'lng': -0.1819544298927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bus-71.png',
#    'icon_background_color': '#10BDFF',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bus_share_taxi_pinlet',
#    'name': 'Finchley Road Station (Stop CH)',
#    'place_id': 'ChIJHZg27IQadkgR8rYm4tGW2w4',
#    'plus_code': {'compound_code': 'GRX9+7Q London, United Kingdom',
#     'global_code': '9C3XGRX9+7Q'},
#    'rating': 1,
#    'reference': 'ChIJHZg27IQadkgR8rYm4tGW2w4',
#    'scope': 'GOOGLE',
#    'types': ['bus_station',
#     'transit_station',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5412969, 'lng': -0.1790611},
#     'viewport': {'northeast': {'lat': 51.54257632989272,
#       'lng': -0.1778513201072778},
#      'southwest': {'lat': 51.53987667010728, 'lng': -0.1805509798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/train-71.png',
#    'icon_background_color': '#10BDFF',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/train_rail_1_pinlet',
#    'name': 'South Hampstead',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102554459648263932957">Farasi Safari</a>'],
#      'photo_reference': 'Aap_uEA94UFLGrIx5cV0n-7SGaGDAfGAymhOwbETb0_nZhXHZug0gXRlLUMu3Jq6vcgh2ySD--2VIW-_NrZs2JrhLPvRBmQ3ET4CZVp-jJ7wdWvVzu0HDdd2icbpWEX9qR1Tuskmpsk5nY522G9GGmNuoqHYxv2v3eNMuduxh7zJzerPIwjT',
#      'width': 4032}],
#    'place_id': 'ChIJH15OLJoadkgRp0fB3C1SeHc',
#    'plus_code': {'compound_code': 'GRRC+G9 London, United Kingdom',
#     'global_code': '9C3XGRRC+G9'},
#    'rating': 3.4,
#    'reference': 'ChIJH15OLJoadkgRp0fB3C1SeHc',
#    'scope': 'GOOGLE',
#    'types': ['train_station',
#     'transit_station',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 13,
#    'vicinity': '156 Loudoun Rd, London'}],
#  'status': 'OK'}

# %% [markdown]
# Near Bar/Cafeteria locals in a 600m radius

# %%
bar_endpoint_ldn = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params_7 = {
    "key": api_google_maps,
    "location": f"{latlnd},{lngldn}",
    "radius": 600,
    "keyword": "bar"
}
params_7_encoded = urlencode(params_7)
bar_url_ldn = f"{bar_endpoint_ldn}?{params_7_encoded}"

r7 = requests.get(bar_url_ldn)

# %%
r7.json()
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.541903, 'lng': -0.180838},
#     'viewport': {'northeast': {'lat': 51.54330152989273,
#       'lng': -0.1794057201072778},
#      'southwest': {'lat': 51.54060187010729, 'lng': -0.1821053798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#    'name': 'The Arches',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 412,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111601843711282724568">NAILast Canary Wharf</a>'],
#      'photo_reference': 'Aap_uEAnhj-7lQJyERFf4Jf0qOILCxuTglmQlF7rF8uU1QGQ0ol00rqqX65nQWTcXKxfsQE3eCm6ErD3YwFHyigN7nst131lyMbDRRhqnxqCOdVoQiUdwp3cIO9m0_d7GEBBToUD0GXltW_kpAi44p73wQembeQF0Y-eODjmVDqlXyBUVTs0',
#      'width': 550}],
#    'place_id': 'ChIJL7f2wpsadkgReecBpZZmNRo',
#    'plus_code': {'compound_code': 'GRR9+QM London, United Kingdom',
#     'global_code': '9C3XGRR9+QM'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJL7f2wpsadkgReecBpZZmNRo',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 219,
#    'vicinity': '7 Fairhazel Gardens, London'}],
#  'status': 'OK'}

# %% [markdown]
# ###### Berlin Company

# %%
latber, lngber = (53.5771514, 10.0115926)

# %% [markdown]
# Near Tech companies in a 500m radius

# %%
techs_endpoint_ber = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params_8 = {
    "key": api_google_maps,
    "location": f"{latber},{lngber}",
    "radius": 500,
    "keyword": "Tech Companies"
}
params_8_encoded = urlencode(params_8)
techs_url_ber = f"{techs_endpoint_ber}?{params_8_encoded}"

r8 = requests.get(techs_url_ber)

# %%
r8.json()
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.58144, 'lng': 10.01001},
#     'viewport': {'northeast': {'lat': 53.58284322989272,
#       'lng': 10.01131842989272},
#      'southwest': {'lat': 53.58014357010727, 'lng': 10.00861877010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Stacklyst Software Engineering GmbH',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1272,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113156346716358176858">A Google User</a>'],
#      'photo_reference': 'Aap_uED_ENCtQuIWq9RUavF9aWNDmr0ii_7XPtJALg2fdzC31bLP3S8VXRzodwkTUNMwpD9F4XDo67sXjd-RDudKOWGkvA1HUY-wUyEb5-4d29zeamob64xuhBnsgAqisZbiIOP4i3AX4YgjUNHz7xMFaQWKwNfrqnBzUPMS63C6xCDjFMqK',
#      'width': 2710}],
#    'place_id': 'ChIJt0kHMeCJsUcRcrs39baR-A0',
#    'plus_code': {'compound_code': 'H2J6+H2 Hamburg, Germany',
#     'global_code': '9F5GH2J6+H2'},
#    'rating': 0,
#    'reference': 'ChIJt0kHMeCJsUcRcrs39baR-A0',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Poelchaukamp 7B, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5815138, 'lng': 10.0180668},
#     'viewport': {'northeast': {'lat': 53.58271827989272,
#       'lng': 10.01948657989272},
#      'southwest': {'lat': 53.58001862010727, 'lng': 10.01678692010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Ceyoniq Technology GmbH - Standort Hamburg',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJ77XWJh-JsUcRpx67y1ADg4Y',
#    'plus_code': {'compound_code': 'H2J9+J6 Hamburg, Germany',
#     'global_code': '9F5GH2J9+J6'},
#    'rating': 0,
#    'reference': 'ChIJ77XWJh-JsUcRpx67y1ADg4Y',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Hans-Henny-Jahnn-Weg 51-53/Gebäude 51, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.57379, 'lng': 10.0140201},
#     'viewport': {'northeast': {'lat': 53.57501767989271,
#       'lng': 10.01542767989272},
#      'southwest': {'lat': 53.57231802010727, 'lng': 10.01272802010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'BJS - Software GmbH',
#    'place_id': 'ChIJ0QTVF9SOsUcRibikYX_FFxY',
#    'plus_code': {'compound_code': 'H2F7+GJ Hamburg, Germany',
#     'global_code': '9F5GH2F7+GJ'},
#    'rating': 0,
#    'reference': 'ChIJ0QTVF9SOsUcRibikYX_FFxY',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Gustav-Freytag-Straße 9, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.58211000000001, 'lng': 10.011176},
#     'viewport': {'northeast': {'lat': 53.58337247989272,
#       'lng': 10.01260687989272},
#      'southwest': {'lat': 53.58067282010728, 'lng': 10.00990722010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'TYPO3 Engineering & Consulting',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJR8iNBfSJsUcRMt6vFYUYjKo',
#    'plus_code': {'compound_code': 'H2J6+RF Hamburg, Germany',
#     'global_code': '9F5GH2J6+RF'},
#    'rating': 0,
#    'reference': 'ChIJR8iNBfSJsUcRMt6vFYUYjKo',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Mühlenkamp 34a, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5781815, 'lng': 10.015333},
#     'viewport': {'northeast': {'lat': 53.57945082989273,
#       'lng': 10.01666057989272},
#      'southwest': {'lat': 53.57675117010728, 'lng': 10.01396092010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'infinity base - powered by ITC',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJk3wQy9SOsUcR5d7rXztcAPI',
#    'plus_code': {'compound_code': 'H2H8+74 Hamburg, Germany',
#     'global_code': '9F5GH2H8+74'},
#    'rating': 0,
#    'reference': 'ChIJk3wQy9SOsUcR5d7rXztcAPI',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Winterhuder Weg 146, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5739721, 'lng': 10.0194995},
#     'viewport': {'northeast': {'lat': 53.57536527989271,
#       'lng': 10.02106342989272},
#      'southwest': {'lat': 53.57266562010727, 'lng': 10.01836377010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': '3MO GmbH',
#    'place_id': 'ChIJ9YuntdOOsUcRxXllf68P1G4',
#    'plus_code': {'compound_code': 'H2F9+HQ Hamburg, Germany',
#     'global_code': '9F5GH2F9+HQ'},
#    'rating': 0,
#    'reference': 'ChIJ9YuntdOOsUcRxXllf68P1G4',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Stormsweg 12, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5817402, 'lng': 10.0099094},
#     'viewport': {'northeast': {'lat': 53.58300822989271,
#       'lng': 10.01132262989272},
#      'southwest': {'lat': 53.58030857010727, 'lng': 10.00862297010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Goviso GmbH',
#    'place_id': 'ChIJmWp7ddWIsUcR3m66-SJnD1c',
#    'plus_code': {'compound_code': 'H2J5+MX Hamburg, Germany',
#     'global_code': '9F5GH2J5+MX'},
#    'rating': 0,
#    'reference': 'ChIJmWp7ddWIsUcR3m66-SJnD1c',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Poelchaukamp 8, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.58106309999999, 'lng': 10.0159305},
#     'viewport': {'northeast': {'lat': 53.58230992989272,
#       'lng': 10.01733892989272},
#      'southwest': {'lat': 53.57961027010727, 'lng': 10.01463927010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'SOG Business-Software GmbH',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 768,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101645231696269601053">SOG Business-Software GmbH</a>'],
#      'photo_reference': 'Aap_uED9y9BfjqKdwLcLV_gqAaVszC30hSAZSxVQu_KUpcNtYnEBdV5zYHXUQsQ70mgE2tMxF-e4q4pl1eLOkAUIBKIPoNVf8TvUhbKsaWkPwVrysCONF3ySxbyZzNUliCU_rTUVRvFx4BKZ5KrzcM6JYwXPYeRZIexapWwqk0gbknNe3oy7',
#      'width': 1536}],
#    'place_id': 'ChIJq7F6pyuJsUcR_QE5KrAQvQg',
#    'plus_code': {'compound_code': 'H2J8+C9 Hamburg, Germany',
#     'global_code': '9F5GH2J8+C9'},
#    'rating': 4.3,
#    'reference': 'ChIJq7F6pyuJsUcR_QE5KrAQvQg',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 14,
#    'vicinity': 'Hans-Henny-Jahnn-Weg 35, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.57438, 'lng': 10.02136},
#     'viewport': {'northeast': {'lat': 53.57583167989272,
#       'lng': 10.02301442989272},
#      'southwest': {'lat': 53.57313202010727, 'lng': 10.02031477010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Web Power Germany GmbH',
#    'place_id': 'ChIJJWitXNKOsUcRKGQOSnlrmIE',
#    'plus_code': {'compound_code': 'H2FC+QG Hamburg, Germany',
#     'global_code': '9F5GH2FC+QG'},
#    'rating': 0,
#    'reference': 'ChIJJWitXNKOsUcRKGQOSnlrmIE',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Winterhuder Weg 29, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5804986, 'lng': 10.0036103},
#     'viewport': {'northeast': {'lat': 53.58183562989272,
#       'lng': 10.00480147989272},
#      'southwest': {'lat': 53.57913597010727, 'lng': 10.00210182010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Sextant Enterprises e. K.',
#    'place_id': 'ChIJZwuhodSIsUcRWiMn_h_g8lY',
#    'plus_code': {'compound_code': 'H2J3+5C Hamburg, Germany',
#     'global_code': '9F5GH2J3+5C'},
#    'rating': 0,
#    'reference': 'ChIJZwuhodSIsUcRWiMn_h_g8lY',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Bellevue 47, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5733, 'lng': 10.01937},
#     'viewport': {'northeast': {'lat': 53.57453877989272,
#       'lng': 10.02077112989272},
#      'southwest': {'lat': 53.57183912010728, 'lng': 10.01807147010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'inquavi',
#    'place_id': 'ChIJA-QXzdOOsUcRGmFEz5mdzLI',
#    'plus_code': {'compound_code': 'H2F9+8P Hamburg, Germany',
#     'global_code': '9F5GH2F9+8P'},
#    'rating': 0,
#    'reference': 'ChIJA-QXzdOOsUcRGmFEz5mdzLI',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Kanalstraße 28, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.57477799999999, 'lng': 10.0152717},
#     'viewport': {'northeast': {'lat': 53.57605522989272,
#       'lng': 10.01661362989272},
#      'southwest': {'lat': 53.57335557010727, 'lng': 10.01391397010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'QSEC® die ISMS und Datenschutz Software der WMC GmbH',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 636,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103179389744556904536">A Google User</a>'],
#      'photo_reference': 'Aap_uEBcj7EJjbRXIaiojj0aJhtjaC8dh-guKToSQvq7YMO5di7XG7tnLua7BU3PbKQG3xQju-jBxdUIaM8-VLTtcByrAMh36iOMeBRFyGAD3pU_5_WsxRY64UgoMT7tebAoB4mZMWkZCFEu3KzSXY33A_i7fChSU-GSuaqx1RJoK74K73XM',
#      'width': 640}],
#    'place_id': 'ChIJCfEfcNSOsUcRrGRKDB0Pww0',
#    'plus_code': {'compound_code': 'H2F8+W4 Hamburg, Germany',
#     'global_code': '9F5GH2F8+W4'},
#    'rating': 0,
#    'reference': 'ChIJCfEfcNSOsUcRrGRKDB0Pww0',
#    'scope': 'GOOGLE',
#    'types': ['electronics_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Zimmerstraße 1, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5734011, 'lng': 10.01832},
#     'viewport': {'northeast': {'lat': 53.57475352989272,
#       'lng': 10.01975492989272},
#      'southwest': {'lat': 53.57205387010728, 'lng': 10.01705527010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'psX Technology GmbH',
#    'photos': [{'height': 3111,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117371487862771947344">A Google User</a>'],
#      'photo_reference': 'Aap_uEDr-SMca1fwXJZGsiWEtZBss5jW5t5ZQsnRhIiiOE8gM4mf1p5RD4lcmV970MJRsxES_hdXr5mLVADhv_P0HJSkvhYIJAsRH6uh2mLvMzx_PlzqJcBDWAJ9fGTkhUnMZzy28O4OgeDUC0bQBeU_ZAN_7f4BFInKHtAwir-TtzndOlwa',
#      'width': 4662}],
#    'place_id': 'ChIJC9vPxNOOsUcRl8ucHvB1PNs',
#    'plus_code': {'compound_code': 'H2F9+98 Hamburg, Germany',
#     'global_code': '9F5GH2F9+98'},
#    'rating': 0,
#    'reference': 'ChIJC9vPxNOOsUcRl8ucHvB1PNs',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Arndtstraße 11A, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.579648, 'lng': 10.0140823},
#     'viewport': {'northeast': {'lat': 53.58096412989272,
#       'lng': 10.01557122989272},
#      'southwest': {'lat': 53.57826447010728, 'lng': 10.01287157010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'SIU Systemhaus für innovative UNIX-Lösungen GmbH',
#    'place_id': 'ChIJ_fGx3yqJsUcRH6Vpy5kNJDo',
#    'plus_code': {'compound_code': 'H2H7+VJ Hamburg, Germany',
#     'global_code': '9F5GH2H7+VJ'},
#    'rating': 0,
#    'reference': 'ChIJ_fGx3yqJsUcRH6Vpy5kNJDo',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Hans-Henny-Jahnn-Weg 9, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.57403, 'lng': 10.01787},
#     'viewport': {'northeast': {'lat': 53.57540312989272,
#       'lng': 10.01942827989272},
#      'southwest': {'lat': 53.57270347010728, 'lng': 10.01672862010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'ICS Labs GmbH',
#    'place_id': 'ChIJJRx0XyWPsUcRkNpaLTYexD4',
#    'plus_code': {'compound_code': 'H2F9+J4 Hamburg, Germany',
#     'global_code': '9F5GH2F9+J4'},
#    'rating': 0,
#    'reference': 'ChIJJRx0XyWPsUcRkNpaLTYexD4',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Arndtstraße 25, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.58259, 'lng': 10.00619},
#     'viewport': {'northeast': {'lat': 53.58393067989272,
#       'lng': 10.00750262989272},
#      'southwest': {'lat': 53.58123102010727, 'lng': 10.00480297010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Yooors GmbH',
#    'place_id': 'ChIJd5UeQ9SIsUcRm3C-IfrXkGw',
#    'plus_code': {'compound_code': 'H2M4+2F Hamburg, Germany',
#     'global_code': '9F5GH2M4+2F'},
#    'rating': 1,
#    'reference': 'ChIJd5UeQ9SIsUcRm3C-IfrXkGw',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Sierichstraße 62, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.574004, 'lng': 10.0127421},
#     'viewport': {'northeast': {'lat': 53.57531917989272,
#       'lng': 10.01395147989272},
#      'southwest': {'lat': 53.57261952010727, 'lng': 10.01125182010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Pharmasynth Technology GmbH',
#    'place_id': 'ChIJKeXbM9SOsUcRqxqCTaVDIJA',
#    'plus_code': {'compound_code': 'H2F7+J3 Hamburg, Germany',
#     'global_code': '9F5GH2F7+J3'},
#    'rating': 0,
#    'reference': 'ChIJKeXbM9SOsUcRqxqCTaVDIJA',
#    'scope': 'GOOGLE',
#    'types': ['health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Herbert-Weichmann-Straße 70, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5767943, 'lng': 10.0182598},
#     'viewport': {'northeast': {'lat': 53.57821007989273,
#       'lng': 10.01958777989272},
#      'southwest': {'lat': 53.57551042010728, 'lng': 10.01688812010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'PLUSaufBAU Software',
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105735902983414207412">A Google User</a>'],
#      'photo_reference': 'Aap_uEBtufaQCx8FHCb-rIM5hG17H7fLcEl5nCOJScabY3-YB2VAhy8hndV256Lj9kZg3cBHwxQZcKN3pxY7FLRhzixLhLd_tu9PBCzGxYe3dbFMzMIFpdn6a2B6WgbOWH-KuLtCJXqy_MU-FP35SXZhzbIoE9jZYpvDVMKzYV0FgP2F2SxS',
#      'width': 4000}],
#    'place_id': 'ChIJr4BEQtOOsUcRevlGhkZq4Rw',
#    'plus_code': {'compound_code': 'H2G9+P8 Hamburg, Germany',
#     'global_code': '9F5GH2G9+P8'},
#    'rating': 0,
#    'reference': 'ChIJr4BEQtOOsUcRevlGhkZq4Rw',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Schenkendorfstraße 26, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.57477369999999, 'lng': 10.0212082},
#     'viewport': {'northeast': {'lat': 53.57596317989272,
#       'lng': 10.02293852989272},
#      'southwest': {'lat': 53.57326352010728, 'lng': 10.02023887010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Brainotech IT Solutions GmbH',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 640,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117965000998499341451">A Google User</a>'],
#      'photo_reference': 'Aap_uEDG8dzVFOv5zZn2QVVGrfNYm03his2FjxT2JCx6AmWHS0Whm-POxID0h_PyeEfV3ZexoJI2-fI8ljQ6F9hOEXPkZViX4XFdBgwVMseJvzfr6wl-iIbInPoo0_aNgriNR5OXPu3No3k0pGgG5Us6RTboEVwGFi0JluQbxXB8RCyP4-SH',
#      'width': 640}],
#    'place_id': 'ChIJSwXkD0ePsUcRpG0ZwHMCHWY',
#    'plus_code': {'compound_code': 'H2FC+WF Hamburg, Germany',
#     'global_code': '9F5GH2FC+WF'},
#    'rating': 5,
#    'reference': 'ChIJSwXkD0ePsUcRpG0ZwHMCHWY',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': 'Winterhuder Weg 29, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5814629, 'lng': 10.0183172},
#     'viewport': {'northeast': {'lat': 53.58269557989272,
#       'lng': 10.01961352989272},
#      'southwest': {'lat': 53.57999592010727, 'lng': 10.01691387010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Resilience Digital Solutions',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 683,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106643319935054141952">A Google User</a>'],
#      'photo_reference': 'Aap_uECuWlvHbxHsi67p6QSXEApnoynaZmHvuXZpKU6uljp-soiXZciRejdkhe6c6AdhKS1MKGhCyVHn8kz5FYMtDYb1n8HYjiA8u9GNZSbP2l8VPOytd1DhVuQuVDF4V6RlwJuVD_XUtaYwyh1ex4pHwTzjwjWoqerxh9vJyJ6p-AfXWo-d',
#      'width': 1024}],
#    'place_id': 'ChIJN3k8ucqJsUcR5jUIeMWB0xc',
#    'plus_code': {'compound_code': 'H2J9+H8 Hamburg, Germany',
#     'global_code': '9F5GH2J9+H8'},
#    'rating': 0,
#    'reference': 'ChIJN3k8ucqJsUcR5jUIeMWB0xc',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Hans-Henny-Jahnn-Weg 53, Hamburg'}],
#  'status': 'OK'}

# %% [markdown]
# Public Transport Services in a 400m radius

# %%
trans_endpoint_ber = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params_9 = {
    "key": api_google_maps,
    "location": f"{latber},{lngber}",
    "radius": 400,
    "keyword": "Public Transport"
}
params_9_encoded = urlencode(params_9)
trans_url_ber = f"{techs_endpoint_ber}?{params_9_encoded}"

r9 = requests.get(trans_url_ber)

# %%
r9.json()
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5786806, 'lng': 10.013709},
#     'viewport': {'northeast': {'lat': 53.58004692989272,
#       'lng': 10.01512092989272},
#      'southwest': {'lat': 53.57734727010728, 'lng': 10.01242127010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Hans-Henny-Jahnn-Weg',
#    'place_id': 'ChIJaz9Q0dSOsUcRtW88a65_07o',
#    'plus_code': {'compound_code': 'H2H7+FF Hamburg, Germany',
#     'global_code': '9F5GH2H7+FF'},
#    'rating': 0,
#    'reference': 'ChIJaz9Q0dSOsUcRtW88a65_07o',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5747833, 'lng': 10.0150175},
#     'viewport': {'northeast': {'lat': 53.57612887989273,
#       'lng': 10.01629907989272},
#      'southwest': {'lat': 53.57342922010728, 'lng': 10.01359942010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Zimmerstraße',
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115367605996641524350">A Google User</a>'],
#      'photo_reference': 'Aap_uEBwEc7JQeSXxPbD0Qd3fJjSI9dcKefZ1BRbkI653zfBITCGHI6EPP7yBdE5AHcKXYo_6EXtxWpWgB9B3eq2YOnP9e51WaWIi6CHjAdwvVnslH6FYVvrUUyXLP2dd7lKgzQ3yJwsLvfmnMaqK_LAvl4b-z0uH1JpTLeR7v13XC4pMUzj',
#      'width': 720}],
#    'place_id': 'ChIJiaXiZdSOsUcR-8EK5iYDza0',
#    'plus_code': {'compound_code': 'H2F8+W2 Hamburg, Germany',
#     'global_code': '9F5GH2F8+W2'},
#    'rating': 0,
#    'reference': 'ChIJiaXiZdSOsUcR-8EK5iYDza0',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5773379, 'lng': 10.0189135},
#     'viewport': {'northeast': {'lat': 53.57868687989272,
#       'lng': 10.02032952989272},
#      'southwest': {'lat': 53.57598722010727, 'lng': 10.01762987010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Hebbelstraße',
#    'place_id': 'ChIJvbPcUdOOsUcRrs0mTEHpOMU',
#    'plus_code': {'compound_code': 'H2G9+WH Hamburg, Germany',
#     'global_code': '9F5GH2G9+WH'},
#    'rating': 2,
#    'reference': 'ChIJvbPcUdOOsUcRrs0mTEHpOMU',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5805979, 'lng': 10.019987},
#     'viewport': {'northeast': {'lat': 53.58204352989272,
#       'lng': 10.02104472989272},
#      'southwest': {'lat': 53.57934387010727, 'lng': 10.01834507010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Herderstraße',
#    'place_id': 'ChIJ8yduiiyJsUcR_1nRXOao6vk',
#    'plus_code': {'compound_code': 'H2J9+6X Hamburg, Germany',
#     'global_code': '9F5GH2J9+6X'},
#    'rating': 0,
#    'reference': 'ChIJ8yduiiyJsUcR_1nRXOao6vk',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5742754, 'lng': 10.0148909},
#     'viewport': {'northeast': {'lat': 53.57562952989272,
#       'lng': 10.01629987989272},
#      'southwest': {'lat': 53.57292987010728, 'lng': 10.01360022010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Zimmerstraße',
#    'photos': [{'height': 3472,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102902778911833882197">A Google User</a>'],
#      'photo_reference': 'Aap_uEBkce_QiiB-bf8bI_6L91cZU2frKvwVL62lGrCMiCIS-2QhmCEbsbvvRGt2RJy8xxquknx9jdfyGgEjl40b6gEU2MVQDQYE2SLiLUoP6scHTq019STWUJ8jp0JKlMaUme8qJfRuRVxAspyPDQx_PvDfXg-D9xFb_AoqBGo1M_GG_NM',
#      'width': 3472}],
#    'place_id': 'ChIJdfambtSOsUcRlMJWIsjIUik',
#    'plus_code': {'compound_code': 'H2F7+PX Hamburg, Germany',
#     'global_code': '9F5GH2F7+PX'},
#    'rating': 4.5,
#    'reference': 'ChIJdfambtSOsUcRlMJWIsjIUik',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': 'Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5793567, 'lng': 10.0128057},
#     'viewport': {'northeast': {'lat': 53.58077752989273,
#       'lng': 10.01410007989272},
#      'southwest': {'lat': 53.57807787010728, 'lng': 10.01140042010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'We Love Almanya',
#    'place_id': 'ChIJq6rTxSqJsUcRRyc91E1DMQo',
#    'plus_code': {'compound_code': 'H2H7+P4 Hamburg, Germany',
#     'global_code': '9F5GH2H7+P4'},
#    'rating': 0,
#    'reference': 'ChIJq6rTxSqJsUcRRyc91E1DMQo',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': '1 Körnerstraße, Hamburg 22301'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5808285, 'lng': 10.0205225},
#     'viewport': {'northeast': {'lat': 53.58193332989272,
#       'lng': 10.02134967989272},
#      'southwest': {'lat': 53.57923367010728, 'lng': 10.01865002010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Herderstraße',
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102231563798531638093">Alexander A. Plagge</a>'],
#      'photo_reference': 'Aap_uEBr1NNQYW_3xpJT43CZeCpgAz2UHxS74A5Gu5Y6_yzhvSODQ2FrCIVpZcQG9nDR3S9t1H-lV6N2pH-KUdJFFDz9SeXmR5hXVRKh6AjNMSsCA4YZYUVGKfncyndCqc_Adbzu4o_PImgRqwjvaENjBUa1H5b0x2uRODRw3idsdvuv3WxJ',
#      'width': 3024}],
#    'place_id': 'ChIJzWYebiyJsUcRghN9wQv_fFE',
#    'plus_code': {'compound_code': 'H2JC+86 Hamburg, Germany',
#     'global_code': '9F5GH2JC+86'},
#    'rating': 3.7,
#    'reference': 'ChIJzWYebiyJsUcRghN9wQv_fFE',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5802226, 'lng': 10.0125207},
#     'viewport': {'northeast': {'lat': 53.58157362989272,
#       'lng': 10.01387437989272},
#      'southwest': {'lat': 53.57887397010727, 'lng': 10.01117472010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Gertigstraße',
#    'place_id': 'ChIJk9mjlCqJsUcRwI1W7dHN4uQ',
#    'plus_code': {'compound_code': 'H2J7+32 Hamburg, Germany',
#     'global_code': '9F5GH2J7+32'},
#    'rating': 0,
#    'reference': 'ChIJk9mjlCqJsUcRwI1W7dHN4uQ',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5786342, 'lng': 10.0140243},
#     'viewport': {'northeast': {'lat': 53.57998447989272,
#       'lng': 10.01537567989272},
#      'southwest': {'lat': 53.57728482010727, 'lng': 10.01267602010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Hans-Henny-Jahnn-Weg',
#    'photos': [{'height': 2250,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105072195268918903811">徐啸宸</a>'],
#      'photo_reference': 'Aap_uEBVUJbQ_eXGl0nqn9XHrCefHsdcVAzXyzt9QXhOBTeea3Mr3zSBhCLbDscL0Y9c8A9_UMsbiXh45-LBzQHzmscwDz7EkVHOVvE4GHu_iOo2Gkr8c_aVq_jqtScF1OaaBw6eXSzW2wqVb6k7ue-KnSJsqgcc2DiNtaQNHU9ifepeRZZM',
#      'width': 4000}],
#    'place_id': 'ChIJ0ZCU1SqJsUcR_3kCSsELKnQ',
#    'plus_code': {'compound_code': 'H2H7+FJ Hamburg, Germany',
#     'global_code': '9F5GH2H7+FJ'},
#    'rating': 4.9,
#    'reference': 'ChIJ0ZCU1SqJsUcR_3kCSsELKnQ',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 9,
#    'vicinity': 'Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5815153, 'lng': 10.0116003},
#     'viewport': {'northeast': {'lat': 53.58285572989273,
#       'lng': 10.01292032989272},
#      'southwest': {'lat': 53.58015607010728, 'lng': 10.01022067010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Gertigstraße',
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112389501353521726250">luis Petrini</a>'],
#      'photo_reference': 'Aap_uEAM-vma4Y8P7ATbgCHblmJqCowxmJ5xqFXlwFm9_7yTi7FDDAVH2qm83zwBs4LGiSIikxYRSEOzxlu7a7M23S2sQtSqn47P7BF_czlWrX_aegL1elz6UZNADRhUddt3tKhkJb0LRN0PZF2Jm62SFNCMSkDKRb8XwRXgnjuhr9GHTuBL',
#      'width': 3024}],
#    'place_id': 'ChIJqwkihiqJsUcRZ3E-TD3nc8c',
#    'plus_code': {'compound_code': 'H2J6+JJ Hamburg, Germany',
#     'global_code': '9F5GH2J6+JJ'},
#    'rating': 3,
#    'reference': 'ChIJqwkihiqJsUcRZ3E-TD3nc8c',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': 'Gertigstraße, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.57898369999999, 'lng': 10.013455},
#     'viewport': {'northeast': {'lat': 53.58035257989273,
#       'lng': 10.01487012989272},
#      'southwest': {'lat': 53.57765292010728, 'lng': 10.01217047010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Fähranleger Mühlenkamp',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109217459204698899916">Joice Yu</a>'],
#      'photo_reference': 'Aap_uEDvOGDLi8BS0kumTHn_aCEXQsiN_B6GlOplRuADUBu_upCUP6-kl4RiQm15naCPPJOCmW6MgIjMAaoxxIWQ4OjTBo3C_Q3nD0MPHjYXl2ggCns9NP4MY_chqVeStRl9OmGV93ILXVhy4Blg1vib0xeHCYe0SHgQHLmQcViKBKvCh_pt',
#      'width': 4032}],
#    'place_id': 'ChIJhcnaXYaJsUcRFPVjyf2lcZc',
#    'plus_code': {'compound_code': 'H2H7+H9 Hamburg, Germany',
#     'global_code': '9F5GH2H7+H9'},
#    'rating': 4,
#    'reference': 'ChIJhcnaXYaJsUcRFPVjyf2lcZc',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Anleger Mühlenkamp, Hofweg 103, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5773778, 'lng': 10.0184464},
#     'viewport': {'northeast': {'lat': 53.57874007989272,
#       'lng': 10.01981252989272},
#      'southwest': {'lat': 53.57604042010728, 'lng': 10.01711287010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Hebbelstraße',
#    'place_id': 'ChIJ5zVCT9OOsUcRXfujhUWjHbA',
#    'plus_code': {'compound_code': 'H2G9+X9 Hamburg, Germany',
#     'global_code': '9F5GH2G9+X9'},
#    'rating': 0,
#    'reference': 'ChIJ5zVCT9OOsUcRXfujhUWjHbA',
#    'scope': 'GOOGLE',
#    'types': ['transit_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Hamburg'}],
#  'status': 'OK'}

# %% [markdown]
# Bar/Cafeteria in a 400m radius

# %%
bar_endpoint_ber = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params_10 = {
    "key": api_google_maps,
    "location": f"{latber},{lngber}",
    "radius": 400,
    "keyword": "bar"
}
params_10_encoded = urlencode(params_10)
bar_url_ber = f"{bar_endpoint_ber}?{params_10_encoded}"

r10 = requests.get(bar_url_ber)

# %%
r10.json()
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.58049399999999, 'lng': 10.0125706},
#     'viewport': {'northeast': {'lat': 53.58182172989272,
#       'lng': 10.01382462989272},
#      'southwest': {'lat': 53.57912207010727, 'lng': 10.01112497010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#    'name': 'Zaza Bar',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 992,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106965784176101225832">A Google User</a>'],
#      'photo_reference': 'Aap_uECETt9sl2A8tLi4dC2_LcAP0LeuVoZO_FWLii5MI5T2JSfBiNTMFn6XCi92MejpDzMNjE2d258eNKKN27PvWDbwh9206h1W7BWBuNom4ojevt0ZsDYXcU7ViL2FR4go2KmSDHk6x0TeiN5H9_2wgiXCzLORzundZBQEyXdUTowErru4',
#      'width': 1354}],
#    'place_id': 'ChIJu12-kiqJsUcR5WPngDZDqfA',
#    'plus_code': {'compound_code': 'H2J7+52 Hamburg, Germany',
#     'global_code': '9F5GH2J7+52'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJu12-kiqJsUcR5WPngDZDqfA',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 209,
#    'vicinity': 'Mühlenkamp 10, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.58066299999999, 'lng': 10.0069477},
#     'viewport': {'northeast': {'lat': 53.58201282989271,
#       'lng': 10.00829752989272},
#      'southwest': {'lat': 53.57931317010727, 'lng': 10.00559787010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'PATIO Restaurant Weinbar',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 712,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117664457962594284177">PATIO Restaurant Weinbar</a>'],
#      'photo_reference': 'Aap_uEAoWkrYO_xABynvGFqgrMr6G8xm0DYm2iE6E_mkKYMAgaUSvu4stTBJJlW6ecJhd5ionIgQ5Dt24MRx0FDrq4Wo2fCuo_NG77sOo70oqQWVumEglgkN_yHDowQGNbbllyt-8znOeJn3Dt-m036ejesqFNl5k6IfvYsNriRHlwtO3zGI',
#      'width': 1080}],
#    'place_id': 'ChIJ4Qol4dSIsUcRsTHQ5qeocmc',
#    'plus_code': {'compound_code': 'H2J4+7Q Hamburg, Germany',
#     'global_code': '9F5GH2J4+7Q'},
#    'price_level': 3,
#    'rating': 4.1,
#    'reference': 'ChIJ4Qol4dSIsUcRsTHQ5qeocmc',
#    'scope': 'GOOGLE',
#    'types': ['restaurant',
#     'bar',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 285,
#    'vicinity': 'Poelchaukamp 33, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.5799082, 'lng': 10.0132317},
#     'viewport': {'northeast': {'lat': 53.58117052989272,
#       'lng': 10.01445442989272},
#      'southwest': {'lat': 53.57847087010727, 'lng': 10.01175477010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#    'name': 'Ratsherrn Bar Mühlenkamp',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 540,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107639306852122117315">Jakob Bollwinkel</a>'],
#      'photo_reference': 'Aap_uEAhTiwhi-vA6d8j2fn7n3FfBqSY1hbT9_4zDXfYFn2eEcmbDD7hB6iwvopLS8d4RwxsOX5p_0yz4otn2VIOfuQLJpTsu6hxz_oVTaXn5tAvUMSYVu4Y-wL8SOVJfXmDMQ_NvnZ548SCoJwYZFEoGCX5rj6xnrsRW_PIXvkqUx6ocpxz',
#      'width': 720}],
#    'place_id': 'ChIJN3Q2_P-JsUcRC7PcF423nAo',
#    'plus_code': {'compound_code': 'H2H7+X7 Hamburg, Germany',
#     'global_code': '9F5GH2H7+X7'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJN3Q2_P-JsUcRC7PcF423nAo',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 284,
#    'vicinity': 'Mühlenkamp 2, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.581171, 'lng': 10.009294},
#     'viewport': {'northeast': {'lat': 53.58249777989272,
#       'lng': 10.01072997989272},
#      'southwest': {'lat': 53.57979812010728, 'lng': 10.00803032010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#    'name': 'Bar Du Nord Winterhude',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115148884638038883344">Dimitrios Beis</a>'],
#      'photo_reference': 'Aap_uEBglhXMZ-R63J3mTu6g_AYVuH0SZrww0G0WLJfQ_DKkIaH39PBVkHXtxftAmWacYk2iTAqXcBU54GN5aKmjcN8IqRPvf6DpaNUT1rlXklwsim-IKFvRLuctf9R23wrxP5P5PJkGItz0D3PAT3XLuaUR-sqsfUk8IBB8IGZaqP-KeWg',
#      'width': 4032}],
#    'place_id': 'ChIJ2xxic9WIsUcRJsnSSE93G80',
#    'plus_code': {'compound_code': 'H2J5+FP Hamburg, Germany',
#     'global_code': '9F5GH2J5+FP'},
#    'rating': 4.1,
#    'reference': 'ChIJ2xxic9WIsUcRJsnSSE93G80',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'night_club', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 143,
#    'vicinity': 'Dorotheenstraße 33, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.58141879999999, 'lng': 10.0135978},
#     'viewport': {'northeast': {'lat': 53.5827686298927,
#       'lng': 10.01494762989272},
#      'southwest': {'lat': 53.58006897010726, 'lng': 10.01224797010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#    'name': 'Berglund Bar',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1667,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100779948819212215518">Berglund Bar</a>'],
#      'photo_reference': 'Aap_uEB-xAfeci9_qDs6Tzlnpw2RNO9cpkSZPwzVfPmw-SsW7I3OD_bUu7Gd04BsazQepejR9Zrlc3LzREjSq9PFT5dGOO_eGjdXNfigVAhaMVRP1fkJ4QPRa51SBCLWMfVeTplu48vZMY3syOpcRwWmya1PK2O1apgY6qyMwD24v_V-Isxx',
#      'width': 2500}],
#    'place_id': 'ChIJpa8WXCqJsUcRGsdH_EeyCKA',
#    'plus_code': {'compound_code': 'H2J7+HC Hamburg, Germany',
#     'global_code': '9F5GH2J7+HC'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJpa8WXCqJsUcRGsdH_EeyCKA',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 371,
#    'vicinity': 'Gertigstraße 14, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.578927, 'lng': 10.0141202},
#     'viewport': {'northeast': {'lat': 53.58020867989272,
#       'lng': 10.01538917989272},
#      'southwest': {'lat': 53.57750902010727, 'lng': 10.01268952010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'TRE PAZZI Café & Bar',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101408025351818196471">A Google User</a>'],
#      'photo_reference': 'Aap_uECI-f9HI5lsE7hupS8F5HN_qYMv3COY0QUZa5ODd6JdTde5NbxGnUjRVpxu5FGY9TOevCFignNklIBLhfKTNxSEtGeR0uhaS7G-U1MAVPKmGRzRFGiuea38u55M-PINJHy3ynA5IPvgZ1QoHYUKOgo-lrDsA5MBh-3ld2G3JdfrflU4',
#      'width': 4032}],
#    'place_id': 'ChIJS5QPovaJsUcRU5RRJruKQlI',
#    'plus_code': {'compound_code': 'H2H7+HJ Hamburg, Germany',
#     'global_code': '9F5GH2H7+HJ'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJS5QPovaJsUcRU5RRJruKQlI',
#    'scope': 'GOOGLE',
#    'types': ['cafe',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 213,
#    'vicinity': 'Hofweg 101, Hamburg'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 53.572722, 'lng': 10.0160921},
#     'viewport': {'northeast': {'lat': 53.57407182989272,
#       'lng': 10.01744192989272},
#      'southwest': {'lat': 53.57137217010728, 'lng': 10.01474227010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#    'name': 'Caipi-Colada',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103328807028904266962">Steffen Damaschke</a>'],
#      'photo_reference': 'Aap_uEDbNTP5gx_J3YY4lBC449FIQAvGW4c7cYz39h0xoNDN3D144gRe6oznt-WLEomYosCAiH7dxz0yD2UlvdaM8Fq4qgC2Y_1DpTU7t5j1NJf-vKeH4hhivt7kIY-li84kctgl_H1EuMKR438HijByBoSuGpchmTonhfC6l0jJkX0VJ2_u',
#      'width': 3024}],
#    'place_id': 'ChIJ50ZOVNGOsUcR3WHKJeHdO_A',
#    'plus_code': {'compound_code': 'H2F8+3C Hamburg, Germany',
#     'global_code': '9F5GH2F8+3C'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJ50ZOVNGOsUcR3WHKJeHdO_A',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 309,
#    'vicinity': 'Kanalstraße 2, Hamburg'}],
#  'status': 'OK'}
